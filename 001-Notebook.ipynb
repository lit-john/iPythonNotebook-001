# %% [markdown]
# # My First iPython Notebook
# This is my first [iPython Notebook](https://ipython.org/)

# %%
print("Python rocks")
# Out:
# Python rocks

# %% [markdown]
# ### The Requests package
# The [Request](http://docs.python-requests.org/en/latest/index.html) package allows for http IO in python.

# %%
import requests

r = requests.get('https://api.github.com/events')

print(r.text)
# Out:
# [{"id":"3963778144","type":"WatchEvent","actor":{"id":4471043,"login":"lucafaggianelli","gravatar_id":"","url":"https://api.github.com/users/lucafaggianelli","avatar_url":"https://avatars.githubusercontent.com/u/4471043?"},"repo":{"id":12716501,"name":"chieffancypants/angular-loading-bar","url":"https://api.github.com/repos/chieffancypants/angular-loading-bar"},"payload":{"action":"started"},"public":true,"created_at":"2016-05-02T21:39:35Z"},{"id":"3963778137","type":"IssuesEvent","actor":{"id":17034,"login":"kevmoo","gravatar_id":"","url":"https://api.github.com/users/kevmoo","avatar_url":"https://avatars.githubusercontent.com/u/17034?"},"repo":{"id":35726310,"name":"dart-lang/sdk","url":"https://api.github.com/repos/dart-lang/sdk"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/dart-lang/sdk/issues/26381","repository_url":"https://api.github.com/repos/dart-lang/sdk","labels_url":"https://api.github.com/repos/dart-lang/sdk/issues/26381/labels{/name}","comm
# ...
